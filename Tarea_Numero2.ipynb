# %% [markdown]
# <a href="https://colab.research.google.com/github/Mario-eliud-pin/edd_1310_2021/blob/master/Tarea_Numero2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
datos=open("Datos.txt","r")
lista_datos="bb"
while lista_datos!="":
  lista_datos=datos.readline()
  lista_datos2=(lista_datos.strip().split())
  for i in range(len(lista_datos2)):
    lista_datos2[i]=lista_datos2[i].strip()
  lista_str="".join(lista_datos2)

  print(lista_str)
  
l_n = open("Datos.txt", 'rt')
dato = l_n.read().replace(" ", "")
res = dato.split("\n")
l = res[0].split(",")
print("Los elementos de la fila 1:")
print(res[0])
print("La suma de la fila 1 es:")

res1 = [int (x) for x in l]
a = sum(res1)
print(a)

dato = l_n.read().replace(" ", "")
l = res[2].split(",")
print("Los elementos de la fila 2:")
print(res[2])
print("La suma de la fila 2 es:")

res2 = [int (x) for x in l]
b = sum(res2)
print(b)

dato = l_n.read().replace(" ", "")
l = res[4].split(",")
print("Los elementos de la fila 3:")
print(res[4])
print("La suma de la fila 3 es:")

res3 = [int (x) for x in l]
c = sum(res3)
print(c)

dato = l_n.read().replace(" ", "")
l = res[6].split(",")
print("Los elementos de la fila 4:")
print(res[6])
print("La suma de la fila 4 es:")

res4 = [int (x) for x in l]
d = sum(res4)
print(d)

dato = l_n.read().replace(" ", "")
l = res[8].split(",")
print("Los elementos de la fila 5:")
print(res[8])
print("La suma de la fila 5 es:")

res5 = [int (x) for x in l]
e = sum(res5)
print(e)

dato = l_n.read().replace(" ", "")
l = res[10].split(",")
print("Los elementos de la fila 6:")
print(res[10])
print("La suma de la fila 6 es:")

res6 = [int (x) for x in l]
f = sum(res6)
print(f)

dato = l_n.read().replace(" ", "")
l = res[12].split(",")
print("Los elementos de la fila 7:")
print(res[12])
print("La suma de la fila 7 es:")

res7 = [int (x) for x in l]
g = sum(res7)
print(g)

dato = l_n.read().replace(" ", "")
l = res[14].split(",")
print("Los elementos de la fila 8:")
print(res[14])
print("La suma de la fila 8 es:")

res8 = [int (x) for x in l]
h = sum(res8)
print(h)

dato = l_n.read().replace(" ", "")
l = res[16].split(",")
print("Los elementos de la fila 9:")
print(res[16])
print("La suma de la fila 9 es:")

res9 = [int (x) for x in l]
i = sum(res9)
print(i)

dato = l_n.read().replace(" ", "")
l = res[18].split(",")
print("Los elementos de la fila 10:")
print(res[18])
print("La suma de la fila 10 es:")

res10 = [int (x) for x in l]
j= sum(res10)
print(j)


def sumar(a,b,c,d,e,f,g,h,i,j):
  r = a+b+c+d+e+f+g+h+i+j 
  return r

print("La suma de las filas es:")
sumar(a,b,c,d,e,f,g,h,i,j)
# Out:
# 1,2,1,14,29,45,5,58,56,10,29,14,88,17,4,3,1,7,12,10
#
# 2,23,5,8,44,2,2,13,5,9,10,16,98,76,47,1,1,3,2
#
# 3,87,15,11,9,7,90,97,21,3,4,1,8,88,74,32,34,43,17,77,93
#
# 4,46,8,1,6,2,10,37,84,4,5,9,10,2,6,31,1,1,8,4,20,33,23,18,45
#
# 55,3,2,29,58,83,9,17,1,43,20,93,31,46,43,77,8,44,45,17,62
#
# 6,74,13,44,18,45,11,93,2,1,1,1,25,1,42,18,22,44,52
#
# 7,88,93,6,54,2,8,1,41,86,79,33,48,9,32,63,18,7,33,2,1,16,11,7
#
# 8,0,22,17,30,6,2,12,47,37,34,85,47,33,2,6,8,4,5,29,30,42,77,2
#
# 9,2,3,4,1,1,3,6,7,7,8,9,5,1,3,4,9,10,12,3,1,5,6,22,11,0,2
#
# 1,0,2,55,9,3,55,23,1,6,9,4,5,3,3,2,1,3,8,1,6,10,0,1,5,1,3
#
# Los elementos de la fila 1:
# 1,2,1,14,29,45,5,58,56,10,29,14,88,17,4,3,1,7,12,10
# La suma de la fila 1 es:
# 406
# Los elementos de la fila 2:
# 2,23,5,8,44,2,2,13,5,9,10,16,98,76,47,1,1,3,2
# La suma de la fila 2 es:
# 367
# Los elementos de la fila 3:
# 3,87,15,11,9,7,90,97,21,3,4,1,8,88,74,32,34,43,17,77,93
# La suma de la fila 3 es:
# 814
# Los elementos de la fila 4:
# ...
