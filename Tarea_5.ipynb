# %% [markdown]
# <a href="https://colab.research.google.com/github/Mario-eliud-pin/edd_1310_2021/blob/master/Tarea_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import copy
import time

class Array2D:
  def __init__(self,rows, cols, value):
    self.__cols = cols
    self.__rows = rows
    self.__array=[[value for x in range(self.__cols)] for y in range(self.__rows)]
    self.life = 1
    self.dead = 1

  def llenar(self, lista):
    for a in range(len(lista)):
        num1 = lista[a][0]
        num2 = lista[a][1]
        self.__array[num1][num2] = 1

  def to_string(self):
    [print("---",end="") for x in range(self.__cols)]
    print("")
    for ren in self.__array:
        print(ren)
    [print("---",end="") for x in range(self.__cols)]
    print("")

  def get_num_rows(self):
    return self.__rows

  def get_num_cols(self):
    return self.__cols

  def get_item(self,row,col):
    return self.__array[row][col]

  def set_item( self , row , col , valor ):
    self.__array[row][col]=valor

  def clearing(self, valor=0):
    for ren in range(self.__rows):
      for col in range(self.__cols):
        self.__array[ren][col]=valor

  def imprime_grid(self):
    for r in range(self.get_num_rows()):
      for c in range(self.get_num_cols()):
        if self.get_item(r,c) == 0:
          print("  ░░ ",end="")
        else:
          print(" ▓▓ ",end="")
      print("")

  def get_numero_vecinos_vivos(self , row , col ):
    limites=[ row-1 , row+1 , col-1 , col+1 ]
    vivos = 0
    if row >= 0 and row <= self.get_num_rows()-1 and col >= 0 and col <= self.get_num_cols()-1:
      for r in range(limites[0],limites[1]+1):
        for c in range(limites[2],limites[3]+1):
          try:
            if self.get_item(r,c) == 1:
              vivos += 1
          except:
            continue
    else :
      print("Coordenada la celula fuera del grid")
    return vivos
  
  def test(self):
    gameaux = copy.deepcopy(self.__array)
    self.life = 0
    self.dead = 0
    for r in range(self.get_num_rows()-1):
      for c in range(self.get_num_cols()-1):
        vecinos = self.get_numero_vecinos_vivos(r,c)
        #print(vecinos)
        if self.__array[r][c] == 1:
          vecinos = vecinos-1
          if vecinos < 2 or vecinos > 3:
            gameaux[r][c] = 0
            self.dead += 1
          else:
            gameaux[r][c] = 1
            self.life += 1
        elif vecinos == 3:
          gameaux[r][c] = 1
          self.life += 1
    
    self.__array = copy.deepcopy(gameaux)


array = Array2D(7,7,0)
array.llenar([(1,2), (2,1), (2,2), (2,3)])
array.imprime_grid()
print("Generacion 1")
print("")

iteraciones = 2
for m in range(7):
  array.test()
  array.imprime_grid()
  print("")
  iteraciones += 1
# Out:
#   ░░   ░░   ░░   ░░   ░░   ░░   ░░
#   ░░   ░░  ▓▓   ░░   ░░   ░░   ░░
#   ░░  ▓▓  ▓▓  ▓▓   ░░   ░░   ░░
#   ░░   ░░   ░░   ░░   ░░   ░░   ░░
#   ░░   ░░   ░░   ░░   ░░   ░░   ░░
#   ░░   ░░   ░░   ░░   ░░   ░░   ░░
#   ░░   ░░   ░░   ░░   ░░   ░░   ░░
# Generacion 1
#
#   ░░   ░░   ░░   ░░   ░░   ░░   ░░
#   ░░  ▓▓  ▓▓  ▓▓   ░░   ░░   ░░
#   ░░  ▓▓  ▓▓  ▓▓   ░░   ░░   ░░
#   ░░   ░░  ▓▓   ░░   ░░   ░░   ░░
#   ░░   ░░   ░░   ░░   ░░   ░░   ░░
#   ░░   ░░   ░░   ░░   ░░   ░░   ░░
#   ░░   ░░   ░░   ░░   ░░   ░░   ░░
#
#   ░░   ░░  ▓▓   ░░   ░░   ░░   ░░
#   ░░  ▓▓   ░░  ▓▓   ░░   ░░   ░░
#   ░░   ░░   ░░   ░░   ░░   ░░   ░░
#   ░░  ▓▓  ▓▓  ▓▓   ░░   ░░   ░░
#   ░░   ░░   ░░   ░░   ░░   ░░   ░░
#   ░░   ░░   ░░   ░░   ░░   ░░   ░░
#   ░░   ░░   ░░   ░░   ░░   ░░   ░░
#
#   ░░   ░░  ▓▓   ░░   ░░   ░░   ░░
#   ░░   ░░  ▓▓   ░░   ░░   ░░   ░░
#   ░░  ▓▓   ░░  ▓▓   ░░   ░░   ░░
#   ░░   ░░  ▓▓   ░░   ░░   ░░   ░░
#   ░░   ░░  ▓▓   ░░   ░░   ░░   ░░
#   ░░   ░░   ░░   ░░   ░░   ░░   ░░
#   ░░   ░░   ░░   ░░   ░░   ░░   ░░
#
#   ░░   ░░   ░░   ░░   ░░   ░░   ░░
#   ░░  ▓▓  ▓▓  ▓▓   ░░   ░░   ░░
#   ░░  ▓▓   ░░  ▓▓   ░░   ░░   ░░
#   ░░  ▓▓  ▓▓  ▓▓   ░░   ░░   ░░
#   ░░   ░░   ░░   ░░   ░░   ░░   ░░
#   ░░   ░░   ░░   ░░   ░░   ░░   ░░
#   ░░   ░░   ░░   ░░   ░░   ░░   ░░
#
#   ░░   ░░  ▓▓   ░░   ░░   ░░   ░░
#   ░░  ▓▓   ░░  ▓▓   ░░   ░░   ░░
#  ▓▓   ░░   ░░   ░░  ▓▓   ░░   ░░
#   ░░  ▓▓   ░░  ▓▓   ░░   ░░   ░░
#   ░░   ░░  ▓▓   ░░   ░░   ░░   ░░
#   ░░   ░░   ░░   ░░   ░░   ░░   ░░
#   ░░   ░░   ░░   ░░   ░░   ░░   ░░
#
#   ░░   ░░  ▓▓   ░░   ░░   ░░   ░░
#   ░░  ▓▓  ▓▓  ▓▓   ░░   ░░   ░░
#  ▓▓  ▓▓   ░░  ▓▓  ▓▓   ░░   ░░
#   ░░  ▓▓  ▓▓  ▓▓   ░░   ░░   ░░
#   ░░   ░░  ▓▓   ░░   ░░   ░░   ░░
#   ░░   ░░   ░░   ░░   ░░   ░░   ░░
#   ░░   ░░   ░░   ░░   ░░   ░░   ░░
#
#   ░░  ▓▓  ▓▓  ▓▓   ░░   ░░   ░░
#  ▓▓   ░░   ░░   ░░  ▓▓   ░░   ░░
#  ▓▓   ░░   ░░   ░░  ▓▓   ░░   ░░
#  ▓▓   ░░   ░░   ░░  ▓▓   ░░   ░░
#   ░░  ▓▓  ▓▓  ▓▓   ░░   ░░   ░░
#   ░░   ░░   ░░   ░░   ░░   ░░   ░░
#   ░░   ░░   ░░   ░░   ░░   ░░   ░░
